# %%
from stock_scraper.infrastructure.db.fetch import fetch_stock_price
import asyncio

# %%
# 例: 日足のAAPLの株価を取得
price_df = await fetch_stock_price(symbol='AAPL', interval='1d')
# Out:
# ❌ DB接続失敗: connection was closed in the middle of operation
# <frozen genericpath>:77: RuntimeWarning: coroutine 'fetch_stock_price' was never awaited
# ...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\selector_events.py:995, in _SelectorSocketTransport._read_ready__data_received(self)
#     994 try:
# --> 995     data = self._sock.recv(self.max_size)
#     996 except (BlockingIOError, InterruptedError):
#
# ConnectionResetError: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
#
# The above exception was the direct cause of the following exception:
#
# ConnectionDoesNotExistError               Traceback (most recent call last)
# File ~\stock_scraper\src\stock_scraper\infrastructure\db\connect.py:38, in make_conn()
#      37     print("❌ DB接続失敗:", e)
# ---> 38     raise e
#      39 finally:
#
# ...
